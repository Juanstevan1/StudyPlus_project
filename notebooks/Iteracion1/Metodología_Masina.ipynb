# %%
import pandas as pd
from IPython.display import display, HTML

# Información básica
basic_info = {
    'Atributos': ['ID', 'Tipo', 'Nombre del agente', 'Descripción', 'Componentes', 'Objetivo', 'Servicios'],
    'Detalles': ['001', 'Agente basado en objetivos', 'Agente Pablo', 'El agente es una herramienta de software diseñada para interactuar con los estudiantes y ayudarlos a gestionar su tiempo de estudio de manera más efectiva. Utiliza técnicas de inteligencia artificial para analizar las notas digitalizadas del estudiante, generar horarios de estudio personalizados y enviar recordatorios para asegurar que el estudiante se mantenga al día con su plan de estudios. Además, el agente es capaz de adaptarse a las necesidades cambiantes del estudiante, ofreciendo recomendaciones y ajustes basados en su rendimiento y progreso.', '', 'El objetivo del agente es proporcionar un asistente virtual para estudiantes que ayuda a mejorar su productividad mediante la organización eficiente de su tiempo de estudio, recordatorios personalizados y la creación de bloques de estudio a partir de sus notas digitalizadas.', 'Optimización del tiempo de estudio, Generación de horarios personalizados, Envío de recordatorios y alertas, Adaptación dinámica del plan de estudio, Recomendaciones personalizadas de estrategias de estudio']
}

# Tareas y servicios
services_and_tasks = {
    'Servicios': ['1 -> Generación de horarios personalizados', '3 -> Envío de recordatorios y alertas','4 -> Adaptación dinámica del plan de estudio','5 -> Recomendaciones personalizadas de estrategias de estudio'],
    'Tareas': [
        '- Recopilación de datos de estudio<br>- Análisis del uso del tiempo<br>- Recopilación de preferencias del estudiante',
        '- Configuración de notificaciones<br>- Implementación de sistema de alertas',
        '- Monitoreo del progreso del estudiante',
        '- Recopilación de información sobre técnicas de estudio<br>- Evaluación del rendimiento'
    ]
}

task1 = {
    'Atributos': ['Nombre', 'Objetivo', 'Descripción'],
    'Detalles': ['Recopilación de datos de estudio', 'Obtener datos relevantes para entender cómo se está utilizando el tiempo de estudio y detectar áreas de mejora.', 'Recolectar información sobre las actividades de estudio del estudiante, incluyendo horarios, temas y métodos utilizados.']
}

task2 = {
    'Atributos': ['Nombre', 'Objetivo', 'Descripción'],
    'Detalles': ['Análisis del uso del tiempo', 'Evaluar la eficiencia del uso del tiempo y encontrar oportunidades para optimizar la planificación del estudio.', 'Examinar los datos de estudio para identificar patrones, hábitos y tiempos dedicados a cada actividad.']
}

task3 = {
    'Atributos': ['Nombre', 'Objetivo', 'Descripción'],
    'Detalles': ['Recopilación de preferencias del estudiante', 'Adaptar el horario de estudio a las preferencias individuales para aumentar la efectividad y satisfacción.', 'Reunir información sobre las preferencias del estudiante en cuanto a horarios, duración y métodos de estudio.']
}

task4 = {
    'Atributos': ['Nombre', 'Objetivo', 'Descripción'],
    'Detalles': ['Configuración de notificaciones', 'Asegurar que el estudiante reciba recordatorios oportunos para mantenerse en el camino con su plan de estudio.', 'Establecer notificaciones para recordar al estudiante sobre las sesiones de estudio y tareas importantes.']
}

task5 = {
    'Atributos': ['Nombre', 'Objetivo', 'Descripción'],
    'Detalles': ['Implementación de sistema de alertas', 'Proporcionar alertas automáticas que ayuden al estudiante a cumplir con los plazos y mantener un ritmo de estudio adecuado.', 'Integrar un sistema que envíe alertas automáticas en función del progreso y los plazos del estudiante.']
}

task6 = {
    'Atributos': ['Nombre', 'Objetivo', 'Descripción'],
    'Detalles': ['Monitoreo del progreso del estudiante', 'Obtener una visión clara del progreso del estudiante para identificar áreas que necesitan ajustes.', 'Supervisar el avance del estudiante en relación con el plan de estudio y las metas establecidas.']
}

task7 = {
    'Atributos': ['Nombre', 'Objetivo', 'Descripción'],
    'Detalles': ['Recopilación de información sobre técnicas de estudio', 'Proporcionar una base sólida de técnicas de estudio que se puedan recomendar de manera personalizada.', 'Investigar y reunir información sobre diversas técnicas y estrategias de estudio que podrían ser útiles para el estudiante.']
}

task8 = {
    'Atributos': ['Nombre', 'Objetivo', 'Descripción'],
    'Detalles': ['Evaluación del rendimiento', 'Obtener una comprensión del rendimiento del estudiante para hacer recomendaciones de estrategias que mejoren su efectividad.', 'Analizar el rendimiento del estudiante para identificar áreas de fortaleza y debilidad en su enfoque de estudio.']
}

# DataFrames
bi = pd.DataFrame(basic_info)
st = pd.DataFrame(services_and_tasks)
t1 = pd.DataFrame(task1)
t2 = pd.DataFrame(task2)
t3 = pd.DataFrame(task3)
t4 = pd.DataFrame(task4)
t5 = pd.DataFrame(task5)
t6 = pd.DataFrame(task6)
t7 = pd.DataFrame(task7)
t8 = pd.DataFrame(task8)

# HTML - CSS
html = """
<style>
    table {{
        width: 100%;
        table-layout: auto;
        border-collapse: collapse;
    }}
    th, td {{
        padding: 8px;
        border: 1px solid #ddd;
        text-align: left;
        word-wrap: break-word;
    }}
    th {{
        background-color: #F796FA;
    }}
    .section {{
        margin-bottom: 20px;
    }}
</style>

<div class="section">
    <h3>Información básica del gemelo:</h3>
    {}
</div>

<div class="section">
    <h3>Tabla de tareas:</h3>
    {}
</div>

<div class="section">
    <h3>Tarea #1:</h3>
    {}
</div>

<div class="section">
    <h3>Tarea #2:</h3>
    {}
</div>

<div class="section">
    <h3>Tarea #3:</h3>
    {}
</div>

<div class="section">
    <h3>Tarea #4:</h3>
    {}
</div>

<div class="section">
    <h3>Tarea #5:</h3>
    {}
</div>

<div class="section">
    <h3>Tarea #6:</h3>
    {}
</div>

<div class="section">
    <h3>Tarea #7:</h3>
    {}
</div>

<div class="section">
    <h3>Tarea #8:</h3>
    {}
</div>

""".format(
    bi.to_html(index=False),
    st.to_html(index=False, escape=False),
    t1.to_html(index=False),
    t2.to_html(index=False),
    t3.to_html(index=False),
    t4.to_html(index=False),
    t5.to_html(index=False),
    t6.to_html(index=False),
    t7.to_html(index=False),
    t8.to_html(index=False)
)

# Mostrar las tablas
display(HTML(html))
# Out:
# <style>
#     table {
#         width: 100%;
#         table-layout: auto;
#         border-collapse: collapse;
#     }
#     th, td {
#         padding: 8px;
#         border: 1px solid #ddd;
#         text-align: left;
#         word-wrap: break-word;
#     }
#     th {
#         background-color: #F796FA;
#     }
#     .section {
#         margin-bottom: 20px;
#     }
# </style>
#
# <div class="section">
#     <h3>Información básica del gemelo:</h3>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Atributos</th>
#       <th>Detalles</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ID</td>
#       <td>001</td>
#     </tr>
#     <tr>
#       <td>Tipo</td>
#       <td>Agente basado en objetivos</td>
#     </tr>
#     <tr>
#       <td>Nombre del agente</td>
#       <td>Agente Pablo</td>
#     </tr>
#     <tr>
#       <td>Descripción</td>
# ...
